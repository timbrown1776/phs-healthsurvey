# %% [markdown]
# ## Load Data

# %%
import pandas as pd
#Ignore the warnings that pandas is giving about dataframe performance
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
# data_file='https://team134chd.s3.amazonaws.com/LLCP2021.XPT+'
data_file='data/LLCP2021.XPT'
#Read SAS file into a dataframe
# df = pd.read_sas('data/LLCP2021.XPT')
df = pd.read_sas(data_file)
#df.head()

# %%
# print('rows=',df.shape[0])
# print('narows=',df['CVDCRHD4'].isna().sum())
# for col in df.columns:
#     if df[col].dtype == 'float64':
#         print('nonzero',col,df[(df[col] > 0.0) & (df[col] < 1.0)].shape[0])

# %%
#there are several values suppose to be zero but are present as 5.397605e-79. So, make them zeroes
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col][df[col] < 0.000000001] = 0.0
# Out:
# C:\Users\timbr\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Drop rows that have the dependent variable as Nan
df.dropna(subset=['CVDCRHD4'],inplace=True)

#del df['_LLCPWT']
#del df['_LLCPWT2']

# %%
# Based on the Data Dictionary below are the Categorical and Continuous variables
Categorical_vars = ['_AGE_G', '_AGE65YR', '_AGEG5YR', '_DRDXAR3', '_LMTACT3', '_BMI5CAT', '_LMTWRK3', 
                    '_CHISPNC', '_CHLDCNT', 'ARTHDIS2', '_CLLCPWT', '_CPRACE1', '_CRACE1', '_CURECI1', 
                    'ARTHEDU', '_DUALCOR', '_DUALUSE', '_EDUCAG', '_FLSHOT7', '_FRT16A', '_FRTLT1A', 
                    '_FRTRES1', '_FRUITE1', '_HCVU652', '_HISPANC', '_HLTHPLN', '_IMPRACE', '_INCOMG1', 
                    'ARTHEXER', 'HAVARTH5', 'JOINPAI2', 'LMTJOIN3', '_METSTAT', '_ASTHMS1', '_MISFRT1', 
                    '_MISVEG1', '_MRACE1', '_PHYS14D', '_PNEUMO3', '_PRACE1', '_RACE', '_RACEG21', '_RACEGR3', 
                    '_RACEPRV', '_RAWRAKE', '_RFBING5', '_RFBMI5', '_CASTHM1', '_RFDRHV7', '_RFHLTH', 
                    '_LTASTH1', '_RFSMOK3', '_SEX', '_SMOKER3', '_STRWT', '_TOTINDA', '_URBSTAT', '_VEG23A', 
                    '_VEGETE1', '_VEGLT1A', '_VEGRES1', '_WT2RAKE', 'ACEADNED', 'ACEADSAF', 'ACEDEPRS', 
                    'ACEDIVRC', 'ACEDRINK', 'ACEDRUGS', 'ACEHURT1', 'ACEHVSEX', 'ACEPRISN', 'ACEPUNCH', 
                    'ACESWEAR', 'ACETOUCH', 'ACETTHEM', 'ASTHMA3', 'ASTHNOW', 'CASTHDX2', 'BLDSTFIT', 
                    'CERVSCRN', 'CHCOCNCR', 'BIRTHSEX', 'CHCSCNCR', 'CNCRDIFF', 'COLNCNCR', 'CADULT1', 
                    'CAGEG', 'CAREGIV1', 'COLNSIGM', 'CASTHNO2', 'CCLGHOUS', 'COLNTES1', 'CRVCLCNC', 
                    'CRVCLHPV', 'CRVCLPAP', 'CSRVCLIN', 'CELLFON5', 'CELLSEX', 'CELPHON1', 'CSRVCTL2', 
                    'CSRVDEIN', 'CSRVDOC1', 'CSRVINSR', 'CSRVINST', 'CHECKUP1', 'CSRVPAIN', 'CSRVRTRN', 
                    'CSRVSUM', 'CSRVTRT3', 'HADHYST2', 'HADMAM', 'HADSIGM4', 'COLGHOUS', 'COLGSEX', 
                    'HOWLONG', 'LASTSIG4', 'LCSCTSCN', 'CPDEMO1B', 'CRGVALZD', 'CRGVEXPT', 'CRGVHOU1', 
                    'CRGVHRS1', 'CRGVLNG1', 'CRGVPER1', 'CRGVPRB3', 'CRGVREL4', 'PCPSARS2', 'PCSTALK', 
                    'PSATEST1', 'PSATIME1', 'SDNATES1', 'SIGMTES1', 'SMALSTOL', 'STOLTEST', 'STOOLDN1', 
                    'VCLNTES1', 'VIRCOLO1', '_MICHD', 'CSTATE1', 'CTELENM1', 'CTELNUM1', 'CVDINFR4', 
                    'CDASSIST', 'CDDISCUS', 'CDHELP', 'CDHOUSE', 'CDSOCIAL', '_CHOLCH3', '_RFCHOL3', '_RFHYPE6', 
                    'DIFFALON', 'BPHIGH6', 'BPMEDS', 'DISPCODE', 'CHOLCHK3', 'CHOLMED3', 'DRNKANY5', 'ECIGNOW1', 
                    'EDUCA', 'EMPLOY1', 'EXERANY2', 'CVDSTRK3', 'DRADVISE', 'HOMBPCHK', 'FIREARM5', 'FLUSHOT7', 
                    'FMONTH', 'GENHLTH', 'GUNLOAD', 'HOMRGCHK', 'SHAREBP', 'TOLDHI3', 'WHEREBP', 'DIABEDU', 
                    'DIABETE4', 'DIABEYE', 'INSULIN1', 'PDIABTST', 'PREDIAB1', 'HPVADSHT', 'HPVADVC4', 'IMFVPLA2', 
                    'IMONTH', 'INCOME3', 'HAVECFS', 'IYEAR', 'TOLDCFS', 'LADULT1', 'LANDLINE', 'LANDSEX', 'DEAF', 
                    'LASTSMK2', 'HAVEHEPB', 'HAVEHEPC', 'LOADULK2', 'MARITAL', 'MEDCOST1', 'MEDSHEPB', 'PRIRHEPC', 
                    'MSCODE', 'NUMADULT', 'NUMHHOL3', 'NUMMEN', 'NUMPHON3', 'NUMWOMEN', 'TOLDHEPC', 'TRETHEPC', 
                    '_AIDTST4', 'PERSDOC3', 'PNEUVAC4', 'HIVTST7', 'PREGNANT', 'PRIMINSR', 'CHCKDNY2', '_MENT14D', 
                    'ADDEPEV3', 'PVTRESD1', 'PVTRESD3', 'QSTLANG', 'QSTVER', 'RCSGENDR', 'RCSRLTN2', 'RENTHOM1', 
                    'RESPSLCT', 'RSNMRJN2', 'SAFETIME', 'CIMEMLOS', 'SEXVAR', 'DECIDE', 'SHINGLE2', 'SMOKDAY2', 
                    'SMOKE100', 'SOFEMALE', 'SOMALE', 'STATERE1', 'DIFFDRES', 'DIFFWALK', 'STOPSMK2', 'TETANUS1', 
                    'CHCCOPD3', 'TRNSGNDR', 'USEMRJN3', 'USENOW3', 'VETERAN3', 'BLIND', 'EYEEXAM1', 'WORKCFS', 'WTCHSALT',#'CVDCRHD4'
                   ]
#-'_PSU'
#+_llcpwt, _llcpwt2
continuous_vars = ['_AGE80', '_BMI5', '_DRNKWK1', '_FRUTSU1',  '_STATE', '_STSTR', '_VEGESU1', 'ALCDAY5', 
                   'AVEDRNK3', 'CNCRAGE', 'CNCRTYP1', 'CHILDREN', 'DRNK3GE5', 'DROCDY3_', 'FLSHTMY3', 'FRENCHF1', 
                   'FRNCHDA_', 'FRUIT2', 'FRUITJU2', 'FRUTDA2_', 'FTJUDA2_', 'FVGREEN1', 'GRENDA1_', 'DIABAGE3', 
                   'HEIGHT3', 'HHADULT', 'DOCTDIAB', 'HTIN4', 'HTM4', 'IDATE', 'IDAY', 'LCSFIRST', 'LCSLAST', 
                   'LCSNUMCG', 'MARIJAN1', 'MAXDRNKS', 'PHYSHLTH', 'POTADA1_', 'POTATOE1', 'HIVTSTD3', 'SEQNO', 
                   'MENTHLTH', 'POORHLTH', 'BLDSUGAR', 'CHKHEMO3', 'FEETCHK', 'FEETCHK3', 'VEGEDA2_', 'VEGETAB2', 
                   'WEIGHT2', 'WTKG3']

# %%
# Categorical_vars = [x.lower() for x in Categorical_vars]
# continuous_vars = [x.lower() for x in continuous_vars]

# Categorical_vars.sort()
# continuous_vars.sort()

# print(pd.DataFrame(Categorical_vars).to_string())
# print(pd.DataFrame(continuous_vars).to_string())
# pd.DataFrame(Categorical_vars)
# print('cat',len(Categorical_vars),Categorical_vars)
# print('cont',len(continuous_vars),continuous_vars)

# %%
# #Get Nan Count for all columns
# na_count = X_train.isna().sum() 
# na_count = pd.DataFrame(na_count).rename(columns={0: 'NA count'})
# na_count = na_count.reset_index()
# #na_count[na_count['index'] == 'CTELENM1']['NA count'].values[0]
# na_count[na_count['NA count'] > 0]

# %%
#Impute columns that has NAN, but have data for atleast half of the data 

for col in df.columns:
    
    #If there are no missing values, skip imputing
#     if na_count[na_count['index'] == col]['NA count'].values[0] == 0:
#         if col in Categorical_vars:
#             X_train[col] = X_train[col].astype('category')
#         else:
#             X_train[col] = X_train[col].astype('float64')
        
#     else:
        
    #If categorical variables and missing values for less than 100 K values, then do mode impute, else impute as missing
    if col in Categorical_vars:

        # if na_count[na_count['index'] == col]['NA count'].values[0] < 150000:                
        #     df[col].fillna(df[col].mode()[0],inplace = True)
            #Cahnge the column to Categorical type
            #X_train[col] = X_train[col].astype('category')
        # else:
        df[col].fillna(999.0,inplace = True)
            #del X_train[col]

        #Cahnge the column to Categorical type
        #X_train[col] = X_train[col].astype('category')

    #If continuous variables and missing values for less than 100 K values, then do mean impute, else impute as 0
    if col in continuous_vars:
        
        # if na_count[na_count['index'] == col]['NA count'].values[0] < 150000:
            # df[col].fillna(df[col].mean(),inplace = True)
            #Cahnge the column to Categorical type
            #X_train[col] = X_train[col].astype('float64')
        # else:
        df[col].fillna(0.0,inplace = True)
            #del X_train[col]

        #Cahnge the column to Categorical type
        #X_train[col] = X_train[col].astype('float64')

#If column has only one value, then delete it            
#if len(X_train[col].unique()) == 1:
#    del X_train[col]
    
df
# Out:
#         _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0          1.0     1.0  b'01192021'  b'01'  b'19'  b'2021'    1100.0
# 1          1.0     1.0  b'01212021'  b'01'  b'21'  b'2021'    1100.0
# 2          1.0     1.0  b'01212021'  b'01'  b'21'  b'2021'    1100.0
# 3          1.0     1.0  b'01172021'  b'01'  b'17'  b'2021'    1100.0
# 4          1.0     1.0  b'01152021'  b'01'  b'15'  b'2021'    1100.0
# ...        ...     ...          ...    ...    ...      ...       ...
# 438688    78.0    12.0  b'01062022'  b'01'  b'06'  b'2022'    1100.0
# 438689    78.0    12.0  b'01122022'  b'01'  b'12'  b'2022'    1100.0
# 438690    78.0    12.0  b'12212021'  b'12'  b'21'  b'2021'    1100.0
# 438691    78.0    12.0  b'01112022'  b'01'  b'11'  b'2022'    1100.0
# 438692    78.0    12.0  b'12222021'  b'12'  b'22'  b'2021'    1100.0
#
#                 SEQNO          _PSU  CTELENM1  ...  _FRTRES1  _VEGRES1  \
# ...

# %%
#encode and normalize the data
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
for x in Categorical_vars:
    df[x]=enc.fit_transform(df[x])

# %%
df['CVDCRHD4']
# Out:
# 0         2.0
# 1         1.0
# 2         1.0
# 3         2.0
# 4         7.0
#          ...
# 438688    2.0
# 438689    2.0
# 438690    2.0
# 438691    2.0
# 438692    2.0
# Name: CVDCRHD4, Length: 438691, dtype: float64

# %% [markdown]
# ## Split the Data into Train and Test Datasets

# %%
#References - https://www.naukri.com/learning/articles/feature-selection-techniques-python-code/

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

y = df['CVDCRHD4']

X = df.drop(['CVDCRHD4'],axis = 1) # frop columns -> axis =1

#Split the Data into train and test data


X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=100,test_size=0.3)

# %%
# X_train['HAVARTH5']
# enc_df = pd.DataFrame(enc.fit_transform(X_train[Categorical_vars]).toarray())
# enc_df

# %%
# X_train['HAVARTH5'].dtype

# %%
#from sklearn.decomposition import PCA

#pca = PCA(n_components = 50, svd_solver='full')
#X_train_pca = pca.fit(X_train)
#X_test_pca = pca.transform(X_test)

# %%
#print(pca.explained_variance_ratio_)
#print(pca.singular_values_)

# %% [markdown]
# ## Find Correlated Coefficients

# %%
def correlation(dataset, threshold):
    col_corr = set()  
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: 
                colname = corr_matrix.columns[i]                  
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_train, 0.7)

corr_features
# Out:
# {'ACEADNED',
#  'ACEADSAF',
#  'ACEDIVRC',
#  'ACEDRINK',
#  'ACEDRUGS',
#  'ACEHURT1',
#  'ACEHVSEX',
#  'ACEPRISN',
#  'ACEPUNCH',
#  'ACESWEAR',
#  'ACETOUCH',
#  'ACETTHEM',
#  'ARTHDIS2',
#  'ARTHEDU',
#  'ARTHEXER',
#  'ASTHNOW',
#  'BLIND',
#  'BPMEDS',
#  'CADULT1',
#  'CAGEG',
#  'CASTHDX2',
#  'CDASSIST',
#  'CDDISCUS',
#  'CDHELP',
#  'CDSOCIAL',
#  'CELLFON5',
#  'CELLSEX',
#  'CELPHON1',
#  'CERVSCRN',
#  'CHOLMED3',
#  'CNCRAGE',
#  'CNCRTYP1',
#  'COLGSEX',
#  'COLNCNCR',
#  'COLNSIGM',
#  'COLNTES1',
#  'CRGVALZD',
#  'CRGVEXPT',
#  'CRGVHOU1',
#  'CRGVHRS1',
#  'CRGVLNG1',
#  'CRGVPER1',
#  'CRGVPRB3',
#  'CRVCLCNC',
#  'CRVCLHPV',
#  'CRVCLPAP',
#  'CSRVCLIN',
#  'CSRVDEIN',
#  'CSRVDOC1',
#  'CSRVINSR',
#  'CSRVINST',
#  'CSRVPAIN',
#  'CSRVRTRN',
#  'CSRVSUM',
#  'CSRVTRT3',
#  'CSTATE1',
#  'CTELNUM1',
#  'DECIDE',
#  'DIABAGE3',
#  'DIABEDU',
#  'DIABEYE',
#  'DIFFALON',
#  'DIFFDRES',
#  'DIFFWALK',
#  'DRADVISE',
#  'DROCDY3_',
#  'ECIGNOW1',
#  'EYEEXAM1',
# ...

# %%
corr_matrixrr = set()  
corr_matrix = X_train.corr()
threshold=.7
col_corr = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > threshold: 
            colname = corr_matrix.columns[i]                  
            col_corr.add(colname)
            #print(f"{colname}:{corr_matrix.iloc[i, j]}")

# %%
corr_matrix
# Out:
#             _STATE    FMONTH    IMONTH     IYEAR  DISPCODE      _PSU  \
# _STATE    1.000000  0.023994 -0.013937  0.078341 -0.011406  0.046550
# FMONTH    0.023994  1.000000  0.696345  0.347826  0.018974  0.207283
# IMONTH   -0.013937  0.696345  1.000000 -0.377746  0.000554  0.116787
# IYEAR     0.078341  0.347826 -0.377746  1.000000  0.062031  0.111698
# DISPCODE -0.011406  0.018974  0.000554  0.062031  1.000000  0.032324
# ...            ...       ...       ...       ...       ...       ...
# _VEGLT1A  0.001131  0.022584  0.013827  0.037051  0.484301  0.027938
# _FRT16A   0.002698 -0.008679 -0.006463  0.002594  0.006989 -0.046838
# _VEG23A   0.001947 -0.008253 -0.007563  0.005910  0.010441 -0.057257
# _FRUITE1 -0.005999  0.020661  0.011477  0.030604  0.491887  0.045981
# _VEGETE1 -0.006466  0.022972  0.014388  0.030153  0.500432  0.053471
#
#           CTELENM1  PVTRESD1  COLGHOUS  STATERE1  ...  _FRTRES1  _VEGRES1  \
# ...

# %%
df=X_train.copy()
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
corr_features = col_corr 
len(corr_features)
# Out:
# 163

# %% [markdown]
# ## Remove Correlated features

# %%
corr_features = col_corr 
X_train = X_train.drop(corr_features,axis=1)
X_test = X_test.drop(corr_features,axis=1)
X_train
# Out:
#         _STATE  FMONTH        IDATE  IMONTH   IDAY  IYEAR  DISPCODE  \
# 78223     16.0       5  b'06172021'       5  b'17'      0         0
# 150704    24.0       5  b'07172021'       6  b'17'      0         0
# 172657    26.0       3  b'04162021'       3  b'16'      0         0
# 209037    29.0      11  b'12312021'      11  b'31'      0         0
# 28291      6.0       5  b'09012021'       8  b'01'      0         1
# ...        ...     ...          ...     ...    ...    ...       ...
# 339801    44.0       9  b'10272021'       9  b'27'      0         1
# 253801    35.0      11  b'01152022'       0  b'15'      1         1
# 210757    30.0      11  b'12272021'      11  b'27'      0         0
# 56090     11.0      10  b'11302021'      10  b'30'      0         1
# 300554    38.0       0  b'02192021'       1  b'19'      0         0
#
#                 SEQNO          _PSU  CTELENM1  ...  _BMI5CAT  _CHLDCNT  \
# 78223   b'2021003756'  2.021004e+09         2  ...         3         0
# ...

# %%
 X_train = X_train.reset_index(drop=True)

#y_train = y_train.astype('category')

# %%
#drop Objects

del X_train['IDATE']
del X_train['IMONTH']
del X_train['IDAY']
del X_train['IYEAR']
del X_train['SEQNO']

# for tets too

del X_test['IDATE']
del X_test['IMONTH']
del X_test['IDAY']
del X_test['IYEAR']
del X_test['SEQNO']

# %%
# set max display cols
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
#for col in X_train.columns:
#    print(col, X_train[col].dtype)
X_train
# Out:
#         _STATE  FMONTH  DISPCODE          _PSU  CTELENM1  COLGHOUS  LANDSEX  \
# 0         16.0       5         0  2.021004e+09         2         1        4
# 1         24.0       5         0  2.021007e+09         2         1        4
# 2         26.0       3         0  2.021005e+09         2         1        4
# 3         29.0      11         0  2.021012e+09         2         1        4
# 4          6.0       5         1  2.021007e+09         2         1        4
# ...        ...     ...       ...           ...       ...       ...      ...
# 307078    44.0       9         1  2.021004e+09         2         1        4
# 307079    35.0      11         1  2.021006e+09         2         1        4
# 307080    30.0      11         0  2.021001e+09         0         1        4
# 307081    11.0      10         1  2.021001e+09         0         1        1
# 307082    38.0       0         0  2.021002e+09         2         1        4
#
# ...

# %% [markdown]
# ## Perform Chi - Square test

# %%
#Reference - https://scikit-learn.org/stable/modules/feature_selection.html
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import chi2

#Calculating Fscore and p value
f_p_values=chi2(X_train,y_train)
f_p_values
# Out:
# (array([1.19933401e+02, 1.41456675e+00, 1.85679014e+02, 5.84223494e+00,
#         1.33858232e+03, 3.39311415e-04, 6.74954450e+02, 7.59108536e+02,
#         9.87174447e-02, 7.18215111e+03, 4.41180758e+02, 1.00564186e+04,
#         4.45983656e+04, 1.76536087e+03, 1.09829116e+04, 2.34114758e+03,
#         4.70578945e+02, 6.39404094e+01, 4.40585213e+03, 2.16359383e+03,
#         9.36465812e+03, 2.84601177e+03, 6.01252463e+03, 3.47465326e+03,
#         8.61769379e+02, 7.59890136e+02, 8.28240862e+02, 8.16478578e+02,
#         1.09732070e+03, 8.45746221e+02, 7.18934996e+02, 2.51049234e+03,
#         2.88061905e+03, 1.66261856e+03, 2.98360780e+02, 2.14024085e+03,
#         4.13756340e+02, 7.84896512e+03, 4.04838598e+02, 2.80361063e+04,
#         6.17883865e+04, 1.73125278e+03, 1.20516257e+03, 9.61766633e+06,
#         6.78287183e+06, 5.54585748e+02, 1.60023040e+03, 3.89933153e+05,
#         1.62904529e+03, 2.06182246e+04, 5.49488823e+03, 1.51047757e+03,
# ...

# %%
# X_train[X_train.isna().sum() > 0]

# %%
import pandas as pd
p_values=pd.Series(f_p_values[1])
p_values.index=X_train.columns
p_values
# Out:
# _STATE       7.975905e-26
# FMONTH       7.021238e-01
# DISPCODE     5.235477e-40
# _PSU         1.195433e-01
# CTELENM1    6.253600e-290
# COLGHOUS     9.999983e-01
# LANDSEX     5.658778e-146
# NUMMEN      3.194029e-164
# CCLGHOUS     9.919909e-01
# HHADULT      0.000000e+00
# SEXVAR       2.654880e-95
# GENHLTH      0.000000e+00
# PHYSHLTH     0.000000e+00
# MENTHLTH     0.000000e+00
# POORHLTH     0.000000e+00
# PRIMINSR     0.000000e+00
# PERSDOC3    1.133070e-101
# MEDCOST1     8.452474e-14
# CHECKUP1     0.000000e+00
# EXERANY2     0.000000e+00
# BPHIGH6      0.000000e+00
# CHOLCHK3     0.000000e+00
# TOLDHI3      0.000000e+00
# CVDINFR4     0.000000e+00
# CVDSTRK3    1.734985e-186
# ASTHMA3     2.161919e-164
# CHCSCNCR    3.245816e-179
# CHCOCNCR    1.154444e-176
# CHCCOPD3    1.387842e-237
# ADDEPEV3    5.183394e-183
# CHCKDNY2    1.644890e-155
# DIABETE4     0.000000e+00
# HAVARTH5     0.000000e+00
# MARITAL      0.000000e+00
# EDUCA        2.251849e-64
# ...

# %%
# p_values.sort_index(ascending=False)

# %%
p_values[p_values < 0.05]
# Out:
# _STATE       7.975905e-26
# DISPCODE     5.235477e-40
# CTELENM1    6.253600e-290
# LANDSEX     5.658778e-146
# NUMMEN      3.194029e-164
# HHADULT      0.000000e+00
# SEXVAR       2.654880e-95
# GENHLTH      0.000000e+00
# PHYSHLTH     0.000000e+00
# MENTHLTH     0.000000e+00
# POORHLTH     0.000000e+00
# PRIMINSR     0.000000e+00
# PERSDOC3    1.133070e-101
# MEDCOST1     8.452474e-14
# CHECKUP1     0.000000e+00
# EXERANY2     0.000000e+00
# BPHIGH6      0.000000e+00
# CHOLCHK3     0.000000e+00
# TOLDHI3      0.000000e+00
# CVDINFR4     0.000000e+00
# CVDSTRK3    1.734985e-186
# ASTHMA3     2.161919e-164
# CHCSCNCR    3.245816e-179
# CHCOCNCR    1.154444e-176
# CHCCOPD3    1.387842e-237
# ADDEPEV3    5.183394e-183
# CHCKDNY2    1.644890e-155
# DIABETE4     0.000000e+00
# HAVARTH5     0.000000e+00
# MARITAL      0.000000e+00
# EDUCA        2.251849e-64
# RENTHOM1     0.000000e+00
# NUMPHON3     2.319053e-89
# CPDEMO1B     0.000000e+00
# VETERAN3     1.981824e-87
# ...

# %%
len(p_values[p_values < 0.05])
# Out:
# 111

# %% [markdown]
# ## Mutual information gain

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
# Out:
# array([3.32064931e-03, 4.77445835e-03, 2.39600122e-03, 1.56392404e-03,
#        5.47848580e-02, 6.72440543e-02, 6.25802905e-02, 5.14425192e-02,
#        6.59999718e-02, 1.58360074e-02, 2.09259094e-02, 3.77312203e-02,
#        5.19801529e-02, 3.84010577e-02, 2.32872949e-02, 2.04463461e-02,
#        1.38963498e-02, 5.79963811e-02, 7.55314111e-03, 7.71960571e-03,
#        6.13740809e-02, 2.79441626e-02, 3.68280244e-02, 1.17138154e-01,
#        7.63189775e-02, 5.47298450e-02, 6.33451046e-02, 6.31159151e-02,
#        7.06199131e-02, 4.79436967e-02, 7.41475483e-02, 7.02892637e-02,
#        4.55543156e-02, 1.61549301e-02, 2.53179793e-02, 6.45675724e-03,
#        7.57674301e-02, 2.99948306e-03, 5.60057279e-02, 3.10429470e-02,
#        5.17602149e-02, 1.10985779e-02, 5.96115408e-02, 5.39762466e-03,
#        4.12291742e-03, 5.87032546e-02, 4.55946249e-02, 2.30138275e-02,
#        6.09796147e-03, 2.50354259e-02, 5.33704171e-03, 1.83833256e-02,
# ...

# %% [markdown]
# ## Representing in list form

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# CVDINFR4    0.117138
# CVDSTRK3    0.076319
# CRGVREL4    0.075904
# NUMPHON3    0.075767
# CHCKDNY2    0.074148
# HPVADSHT    0.072671
# CSRVCTL2    0.071679
# HPVADVC4    0.070796
# CNCRDIFF    0.070664
# CHCCOPD3    0.070620
# DIABETE4    0.070289
# WHEREBP     0.069004
# MEDSHEPB    0.068200
# LCSCTSCN    0.067530
# CASTHNO2    0.067355
# PSATEST1    0.067297
# COLGHOUS    0.067244
# VIRCOLO1    0.067237
# INSULIN1    0.067075
# HADSIGM4    0.066526
# TOLDHEPC    0.066158
# SHINGLE2    0.066112
# CCLGHOUS    0.066000
# HADMAM      0.065854
# USEMRJN3    0.065754
# CHCSCNCR    0.063345
# STOPSMK2    0.063174
# CHCOCNCR    0.063116
# LANDSEX     0.062580
# CIMEMLOS    0.062291
# WTCHSALT    0.061568
# LASTSMK2    0.061453
# BPHIGH6     0.061374
# FIREARM5    0.061349
# BLDSTFIT    0.060425
# TRETHEPC    0.059914
# PREGNANT    0.059612
# SIGMTES1    0.059473
# DEAF        0.058703
# MEDCOST1    0.057996
# TETANUS1    0.057510
# ACEDEPRS    0.057250
# VETERAN3    0.056006
# ...

# %%
from sklearn.feature_selection import SelectKBest
#Now we Will select the top k important features
sel_k_cols = SelectKBest(mutual_info_classif, k=50)
sel_k_cols.fit(X_train, y_train)
X_train.columns[sel_k_cols.get_support()]
# Out:
# Index(['CTELENM1', 'COLGHOUS', 'LANDSEX', 'CCLGHOUS', 'PHYSHLTH', 'MEDCOST1',
#        'BPHIGH6', 'CVDINFR4', 'CVDSTRK3', 'ASTHMA3', 'CHCSCNCR', 'CHCOCNCR',
#        'CHCCOPD3', 'CHCKDNY2', 'DIABETE4', 'NUMPHON3', 'VETERAN3', 'PREGNANT',
#        'DEAF', 'INSULIN1', 'TOLDHEPC', 'TRETHEPC', 'MEDSHEPB', 'HPVADVC4',
#        'HPVADSHT', 'TETANUS1', 'SHINGLE2', 'LCSCTSCN', 'HADMAM', 'PSATEST1',
#        'HADSIGM4', 'SIGMTES1', 'VIRCOLO1', 'VCLNTES1', 'BLDSTFIT', 'CNCRDIFF',
#        'CSRVCTL2', 'WHEREBP', 'WTCHSALT', 'CIMEMLOS', 'CDHOUSE', 'CRGVREL4',
#        'ACEDEPRS', 'USEMRJN3', 'LASTSMK2', 'STOPSMK2', 'FIREARM5', 'RCSGENDR',
#        'CASTHNO2', '_HISPANC'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()
model1.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
predictions= model1.predict(X_test)
percentage= model1.score(X_test,y_test)
res=confusion_matrix(y_test,predictions)
print("confusion matrix")
print(res)
# check the accuracy on the training set
print(model1.score(X_train, y_train))
print(model1.score(X_test, y_test))
print(f"Test set:{len(X_test)}")
print(f"Accuracy={percentage*100}%")
# Out:
# confusion matrix
# [[     0   6989      0      0]
#  [     0 123355      0      0]
#  [     0   1172      0      0]
#  [     0     92      0      0]]
# 0.9384173008600281
# 0.937291046137013
# Test set:131608
# Accuracy=93.7291046137013%

# %%
#remove where coef are close to zero
coef = model1.coef_[0]
imp_features = pd.Series(X_train.columns)[list(coef!=0)]
# X_train = X_train[imp_features]
# X_test = X_test[imp_features]
len(imp_features)
# Out:
# 131

# %%
coef
# Out:
# array([ 1.07322444e-17,  6.60652416e-19, -7.42247715e-19,  3.73354511e-10,
#        -5.53985443e-18,  1.83483852e-19, -5.35232696e-18, -1.06247674e-17,
#         2.28743783e-19, -1.01384245e-17, -2.04748287e-18,  1.65530858e-17,
#        -2.13388324e-16,  4.01709254e-17,  6.31249996e-17,  1.50016468e-18,
#         2.94869676e-19,  2.23856950e-19, -4.81573177e-18,  2.53864029e-18,
#        -1.38201815e-17, -7.67637970e-18, -1.07745609e-17, -7.17639733e-18,
#        -1.94137046e-18, -8.81143624e-19, -1.83921339e-18, -1.64712770e-18,
#        -2.92003134e-18, -1.05606623e-18, -1.87506373e-18, -7.53553988e-18,
#        -4.95432825e-18, -5.01309143e-18, -2.25818439e-18, -1.51898271e-18,
#        -6.71894079e-18,  4.10376777e-18, -1.97799212e-18,  3.72391598e-17,
#         2.83069591e-16, -1.18408994e-17,  9.33408875e-18, -3.31027234e-15,
#        -2.16446155e-15, -2.54274802e-18, -9.44826629e-18,  1.80186016e-15,
# ...

# %%
#### option 2 
# select top 13 attribs and run logistic regression with them
from sklearn.feature_selection import SelectKBest
#Now we Will select the top k important features
sel_k_cols = SelectKBest(mutual_info_classif, k=13)
sel_k_cols.fit(X_train, y_train)
top10Cols=X_train.columns[sel_k_cols.get_support()]

# %%
X_train=X_train[top10Cols]
X_test=X_test[top10Cols]

# %%
from sklearn.linear_model import LogisticRegression
model2=LogisticRegression()
model2.fit(X_train,y_train)
# Out:
# C:\Users\timbr\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
predictions= model2.predict(X_test)
percentage= model2.score(X_test,y_test)
res=confusion_matrix(y_test,predictions)
print("confusion matrix")
print(res)
# check the accuracy on the training set
# print(model2.score(X_train, y_train))
print(model2.score(X_test, y_test))
print(f"Test set:{len(X_test)}")
print(f"Accuracy={percentage*100}%")
# Out:
# confusion matrix
# [[  1510   5479      0      0]
#  [  1162 122188      0      5]
#  [   138   1032      0      2]
#  [     3     36      0     53]]
# 0.9402999817640265
# Test set:131608
# Accuracy=94.02999817640266%

# %%
coef = model1.coef_[0]
coef
# Out:
# array([ 1.07322444e-17,  6.60652416e-19, -7.42247715e-19,  3.73354511e-10,
#        -5.53985443e-18,  1.83483852e-19, -5.35232696e-18, -1.06247674e-17,
#         2.28743783e-19, -1.01384245e-17, -2.04748287e-18,  1.65530858e-17,
#        -2.13388324e-16,  4.01709254e-17,  6.31249996e-17,  1.50016468e-18,
#         2.94869676e-19,  2.23856950e-19, -4.81573177e-18,  2.53864029e-18,
#        -1.38201815e-17, -7.67637970e-18, -1.07745609e-17, -7.17639733e-18,
#        -1.94137046e-18, -8.81143624e-19, -1.83921339e-18, -1.64712770e-18,
#        -2.92003134e-18, -1.05606623e-18, -1.87506373e-18, -7.53553988e-18,
#        -4.95432825e-18, -5.01309143e-18, -2.25818439e-18, -1.51898271e-18,
#        -6.71894079e-18,  4.10376777e-18, -1.97799212e-18,  3.72391598e-17,
#         2.83069591e-16, -1.18408994e-17,  9.33408875e-18, -3.31027234e-15,
#        -2.16446155e-15, -2.54274802e-18, -9.44826629e-18,  1.80186016e-15,
# ...

# %%
top10Cols
# Out:
# Index(['CVDINFR4', 'CVDSTRK3', 'CHCCOPD3', 'CHCKDNY2', 'DIABETE4', 'NUMPHON3',
#        'HPVADVC4', 'HPVADSHT', 'VIRCOLO1', 'CNCRDIFF', 'CSRVCTL2', 'WHEREBP',
#        'CRGVREL4'],
#       dtype='object')

# %%
#store the model in using pickle in file
import pickle
filename = 'model\team134_top10.sav'
pickle.dump(model2, open(filename, 'wb'))

# %%
# load the model
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.9402999817640265

# %%
# import pandas as pd
# p=pd.DataFrame(data=[[0,1,1,0,1,9,1,30,2,
#                                         3,
#                                         1,1,1]],
#                                  columns=['Unnamed: 0','CVDSTRK3','SMOKDAY2','DIABETE4','CHCKDNY2','CHCSCNCR','ASTHMA3',
#                                           'EXERANY2','MENTHLTH',
#                                           'PHYSHLTH','GENHLTH','X_PRACE1','LANDSEX'])

# %%
# import pickle
# loaded_model = pickle.load(open('cse6242-project/model/CHD_model.sav', 'rb'))
# # result = loaded_model.score(X_test, y_test)
# # print(result)
# result=loaded_model.predict(p)

# %%
# result[0]
